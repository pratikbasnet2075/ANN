# %% [markdown]
# <a href="https://colab.research.google.com/github/pratikbasnet2075/ANN/blob/main/Perceptron_for_2_input_Basic_Gates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

class Perceptron:
    def __init__(self, input_size, lr=0.1):
        self.weights = np.zeros(input_size)
        self.bias = 0
        self.lr = lr

    def activation(self, x):
        return 1 if x >= 0 else 0

    def predict(self, x):
        summation = np.dot(x, self.weights) + self.bias
        return self.activation(summation)

    def train(self, X, y, epochs=100):
        for epoch in range(epochs):
            print(f"Epoch {epoch + 1}")
            for xi, target in zip(X, y):
                prediction = self.predict(xi)
                error = target - prediction
                self.weights += self.lr * error * xi
                self.bias += self.lr * error
            print(f"Weights: {self.weights}, Bias: {self.bias}")

        # Final accuracy
        predictions = [self.predict(xi) for xi in X]
        accuracy = np.mean(predictions == y)
        print(f"Final Accuracy: {accuracy * 100:.2f}%")
        return self.weights, self.bias

# Inputs and outputs for AND
X_and = np.array([[0,0], [0,1], [1,0], [1,1]])
y_and = np.array([0, 0, 0, 1])

# Inputs and outputs for OR
X_or = np.array([[0,0], [0,1], [1,0], [1,1]])
y_or = np.array([0, 1, 1, 1])

print("Training for AND Gate:")
perceptron_and = Perceptron(input_size=2)
perceptron_and.train(X_and, y_and)

print("\nTraining for OR Gate:")
perceptron_or = Perceptron(input_size=2)
perceptron_or.train(X_or, y_or)
# Out:
# Training for AND Gate:
# Epoch 1
# Weights: [0.1 0.1], Bias: 0.0
# Epoch 2
# Weights: [0.2 0.1], Bias: -0.1
# Epoch 3
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 4
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 5
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 6
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 7
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 8
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 9
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 10
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 11
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 12
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 13
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 14
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 15
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 16
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 17
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 18
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 19
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 20
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 21
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 22
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 23
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 24
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 25
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 26
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 27
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 28
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 29
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 30
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 31
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 32
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 33
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 34
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 35
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 36
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 37
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 38
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 39
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 40
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 41
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 42
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 43
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 44
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 45
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 46
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 47
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 48
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 49
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 50
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 51
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 52
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 53
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 54
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 55
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 56
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 57
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 58
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 59
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 60
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 61
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 62
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 63
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 64
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 65
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 66
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 67
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 68
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 69
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 70
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 71
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 72
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 73
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 74
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 75
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 76
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 77
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 78
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 79
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 80
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 81
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 82
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 83
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 84
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 85
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 86
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 87
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 88
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 89
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 90
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 91
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 92
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 93
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 94
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 95
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 96
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 97
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 98
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 99
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Epoch 100
# Weights: [0.2 0.1], Bias: -0.20000000000000004
# Final Accuracy: 100.00%
#
# Training for OR Gate:
# Epoch 1
# Weights: [0.  0.1], Bias: 0.0
# Epoch 2
# Weights: [0.1 0.1], Bias: 0.0
# Epoch 3
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 4
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 5
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 6
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 7
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 8
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 9
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 10
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 11
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 12
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 13
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 14
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 15
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 16
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 17
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 18
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 19
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 20
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 21
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 22
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 23
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 24
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 25
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 26
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 27
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 28
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 29
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 30
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 31
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 32
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 33
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 34
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 35
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 36
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 37
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 38
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 39
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 40
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 41
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 42
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 43
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 44
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 45
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 46
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 47
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 48
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 49
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 50
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 51
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 52
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 53
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 54
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 55
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 56
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 57
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 58
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 59
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 60
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 61
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 62
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 63
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 64
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 65
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 66
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 67
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 68
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 69
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 70
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 71
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 72
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 73
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 74
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 75
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 76
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 77
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 78
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 79
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 80
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 81
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 82
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 83
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 84
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 85
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 86
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 87
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 88
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 89
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 90
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 91
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 92
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 93
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 94
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 95
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 96
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 97
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 98
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 99
# Weights: [0.1 0.1], Bias: -0.1
# Epoch 100
# Weights: [0.1 0.1], Bias: -0.1
# Final Accuracy: 100.00%
# (array([0.1, 0.1]), np.float64(-0.1))
